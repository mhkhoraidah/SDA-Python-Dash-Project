# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns 

import plotly.express as px
import plotly.graph_objects as go
from jupyter_dash import JupyterDash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv('Data_Professional_Salary_Survey_Responses.csv')
df.rename(columns={' SalaryUSD ': 'SalaryUSD'}, inplace=True)
df
# Out:
#        Survey Year           Timestamp  SalaryUSD         Country PostalCode  \
# 0             2021  12/10/2020 8:22:43    65,000           Sweden        NaN
# 1             2021  12/10/2020 8:23:22   145,000    United States      76063
# 2             2021  12/10/2020 8:23:38   105,000    United States      43240
# 3             2021  12/10/2020 8:23:48    46,482   United Kingdom        NaN
# 4             2021  12/10/2020 8:24:04    98,800    United States        468
# ...            ...                 ...        ...             ...        ...
# 10336         2017  1/14/2017 15:50:24    36,549   United Kingdom  Not Asked
# 10337         2017   1/15/2017 1:01:21    65,000     Saudi Arabia  Not Asked
# 10338         2017   1/15/2017 3:25:47    85,000      Netherlands  Not Asked
# 10339         2017   1/15/2017 3:37:35    90,000    United States  Not Asked
# 10340         2017   1/15/2017 3:37:59    23,000         Portugal  Not Asked
#
#             PrimaryDatabase  YearsWithThisDatabase  \
# 0      Microsoft SQL Server                      4
# 1      Microsoft SQL Server                     15
# 2      Microsoft SQL Server                     12
# 3      Microsoft SQL Server                     10
# 4      Microsoft SQL Server                      5
# ...                     ...                    ...
# 10336  Microsoft SQL Server                      3
# 10337  Microsoft SQL Server                      7
# 10338  Microsoft SQL Server                     17
# 10339  Microsoft SQL Server                      8
# 10340  Microsoft SQL Server                      4
#
#                                         OtherDatabases    EmploymentStatus  \
# 0                                 Microsoft SQL Server  Full time employee
# 1                            Azure SQL DB (any flavor)  Full time employee
# 2                PostgreSQL, Azure SQL DB (any flavor)  Full time employee
# 3                            Azure SQL DB (any flavor)  Full time employee
# 4                                                  DB2  Full time employee
# ...                                                ...                 ...
# 10336                                              NaN  Full time employee
# 10337  Oracle, MySQL/MariaDB, Microsoft Access, SQLite  Full time employee
# 10338                                           Oracle  Full time employee
# 10339                                    MySQL/MariaDB  Full time employee
# 10340                PostgreSQL, DB2, Microsoft Access  Full time employee
#
#                                                 JobTitle  ...  \
# 0      Developer: Business Intelligence (SSRS, PowerB...  ...
# 1      DBA (Production Focus - build & troubleshoot s...  ...
# 2      DBA (General - splits time evenly between writ...  ...
# 3      DBA (Production Focus - build & troubleshoot s...  ...
# 4      Developer: Business Intelligence (SSRS, PowerB...  ...
# ...                                                  ...  ...
# 10336                                                DBA  ...
# 10337                                                DBA  ...
# 10338                                              Other  ...
# 10339                                                DBA  ...
# 10340                                          Architect  ...
#
#       NewestVersionInProduction  OldestVersionInProduction  \
# 0               SQL Server 2016            SQL Server 2016
# 1               SQL Server 2019            SQL Server 2014
# 2               SQL Server 2017          SQL Server 2008R2
# 3               SQL Server 2019            SQL Server 2012
# 4               SQL Server 2019            SQL Server 2012
# ...                         ...                        ...
# 10336                 Not Asked                  Not Asked
# 10337                 Not Asked                  Not Asked
# 10338                 Not Asked                  Not Asked
# 10339                 Not Asked                  Not Asked
# 10340                 Not Asked                  Not Asked
#
#       PopulationOfLargestCityWithin20Miles  \
# 0                         <= 20,000 (town)
# 1                         1M+ (metropolis)
# 2                     300K-1M (large city)
# 3                     300K-1M (large city)
# 4                         100K-299K (city)
# ...                                    ...
# 10336                            Not Asked
# 10337                            Not Asked
# 10338                            Not Asked
# 10339                            Not Asked
# 10340                            Not Asked
#
#                             EmploymentSector  \
# 0                           Private business
# 1                           Private business
# 2                           Private business
# 3      Education (K-12, college, university)
# 4                           Private business
# ...                                      ...
# 10336                       Private business
# 10337                       Private business
# 10338                       Private business
# 10339                       Private business
# 10340                       Private business
#
#                            LookingForAnotherJob  \
# 0                                     Not Asked
# 1                                     Not Asked
# 2                                     Not Asked
# 3                                     Not Asked
# 4                                     Not Asked
# ...                                         ...
# 10336                                        No
# 10337    Yes, but only passively (just curious)
# 10338    Yes, but only passively (just curious)
# 10339  Yes, actively looking for something else
# 10340    Yes, but only passively (just curious)
#
#                           CareerPlansThisYear     Gender OtherJobDuties  \
# 0      Stay with the same employer, same role       Male      Not Asked
# 1      Stay with the same employer, same role       Male      Not Asked
# 2      Stay with the same employer, same role       Male      Not Asked
# 3      Stay with the same employer, same role       Male      Not Asked
# 4      Stay with the same employer, same role       Male      Not Asked
# ...                                       ...        ...            ...
# 10336                               Not Asked  Not Asked      Not Asked
# 10337                               Not Asked  Not Asked      Not Asked
# 10338                               Not Asked  Not Asked      Not Asked
# 10339                               Not Asked  Not Asked      Not Asked
# 10340                               Not Asked  Not Asked      Not Asked
#
#       KindsOfTasksPerformed Counter
# 0                 Not Asked       1
# 1                 Not Asked       1
# 2                 Not Asked       1
# 3                 Not Asked       1
# 4                 Not Asked       1
# ...                     ...     ...
# 10336             Not Asked       1
# 10337             Not Asked       1
# 10338             Not Asked       1
# 10339             Not Asked       1
# 10340             Not Asked       1
#
# [10341 rows x 31 columns]

# %% [markdown]
# # Show the Count of each Columns

# %%
df.isna().sum()
# Out:
# Survey Year                                0
# Timestamp                                  0
# SalaryUSD                                  0
# Country                                    0
# PostalCode                              1803
# PrimaryDatabase                            0
# YearsWithThisDatabase                      0
# OtherDatabases                          1944
# EmploymentStatus                           0
# JobTitle                                   0
# ManageStaff                                0
# YearsWithThisTypeOfJob                     0
# HowManyCompanies                           0
# OtherPeopleOnYourTeam                      0
# CompanyEmployeesOverall                    0
# DatabaseServers                            0
# Education                                  0
# EducationIsComputerRelated              1212
# Certifications                             0
# HoursWorkedPerWeek                         0
# TelecommuteDaysPerWeek                     0
# NewestVersionInProduction                 14
# OldestVersionInProduction                 13
# PopulationOfLargestCityWithin20Miles       0
# EmploymentSector                           0
# LookingForAnotherJob                       0
# CareerPlansThisYear                        0
# Gender                                     0
# OtherJobDuties                           618
# KindsOfTasksPerformed                    205
# Counter                                    0
# dtype: int64

# %% [markdown]
# # Data Cleaning:

# %% [markdown]
# #### Replacing missing values with np.nan

# %%
missing_val = ['Not Asked']
df.replace(missing_val, np.nan, inplace = True)

# %% [markdown]
# #### Count of Nan's after replacing

# %%
df.isna().sum()
# Out:
# Survey Year                                0
# Timestamp                                  0
# SalaryUSD                                  0
# Country                                    0
# PostalCode                              4701
# PrimaryDatabase                            0
# YearsWithThisDatabase                      0
# OtherDatabases                          1944
# EmploymentStatus                           0
# JobTitle                                   0
# ManageStaff                                0
# YearsWithThisTypeOfJob                     0
# HowManyCompanies                        5992
# OtherPeopleOnYourTeam                      0
# CompanyEmployeesOverall                 7715
# DatabaseServers                         1747
# Education                               3470
# EducationIsComputerRelated              4682
# Certifications                          3470
# HoursWorkedPerWeek                      3470
# TelecommuteDaysPerWeek                  3470
# NewestVersionInProduction               6885
# OldestVersionInProduction               6884
# PopulationOfLargestCityWithin20Miles    5992
# EmploymentSector                           0
# LookingForAnotherJob                    3470
# CareerPlansThisYear                     2898
# Gender                                  2898
# OtherJobDuties                          6986
# KindsOfTasksPerformed                   6573
# Counter                                    0
# dtype: int64

# %% [markdown]
# #### Remove columns that contains NaN more than 30%

# %%
df=df.drop(['PostalCode', 'HowManyCompanies', 'CompanyEmployeesOverall', 'Education', 'EducationIsComputerRelated', 
'Certifications', 'HoursWorkedPerWeek', 'TelecommuteDaysPerWeek', 'NewestVersionInProduction', 'OldestVersionInProduction',
'PopulationOfLargestCityWithin20Miles', 'OtherJobDuties', 'KindsOfTasksPerformed', 'LookingForAnotherJob'], axis = 1)

# %%
df.isna().sum()
# Out:
# Survey Year                  0
# Timestamp                    0
# SalaryUSD                    0
# Country                      0
# PrimaryDatabase              0
# YearsWithThisDatabase        0
# OtherDatabases            1944
# EmploymentStatus             0
# JobTitle                     0
# ManageStaff                  0
# YearsWithThisTypeOfJob       0
# OtherPeopleOnYourTeam        0
# DatabaseServers           1747
# EmploymentSector             0
# CareerPlansThisYear       2898
# Gender                    2898
# Counter                      0
# dtype: int64

# %% [markdown]
# #### Fill nulls values

# %%
df['OtherDatabases'] = df['OtherDatabases'].fillna(df['OtherDatabases'].mode()[0])
df['DatabaseServers'] = df['DatabaseServers'].fillna(df['DatabaseServers'].mode()[0])
df['CareerPlansThisYear'] = df['CareerPlansThisYear'].fillna(df['CareerPlansThisYear'].mode()[0])
# We can't fill the Gender by mode. We assume that it is Unknown
df['Gender'] = df['Gender'].fillna('Unknown')
df['Gender']= df['Gender'].replace(['None'],'Unknown')

# %% [markdown]
# #### Convert to numeric

# %%
#convert to numeric
df['SalaryUSD']=df["SalaryUSD"].str.replace(",","").astype(float)
df['SalaryUSD']= pd.to_numeric(df["SalaryUSD"])
df.head()
# Out:
#    Survey Year           Timestamp  SalaryUSD         Country  \
# 0         2021  12/10/2020 8:22:43    65000.0          Sweden
# 1         2021  12/10/2020 8:23:22   145000.0   United States
# 2         2021  12/10/2020 8:23:38   105000.0   United States
# 3         2021  12/10/2020 8:23:48    46482.0  United Kingdom
# 4         2021  12/10/2020 8:24:04    98800.0   United States
#
#         PrimaryDatabase  YearsWithThisDatabase  \
# 0  Microsoft SQL Server                      4
# 1  Microsoft SQL Server                     15
# 2  Microsoft SQL Server                     12
# 3  Microsoft SQL Server                     10
# 4  Microsoft SQL Server                      5
#
#                           OtherDatabases    EmploymentStatus  \
# 0                   Microsoft SQL Server  Full time employee
# 1              Azure SQL DB (any flavor)  Full time employee
# 2  PostgreSQL, Azure SQL DB (any flavor)  Full time employee
# 3              Azure SQL DB (any flavor)  Full time employee
# 4                                    DB2  Full time employee
#
#                                             JobTitle ManageStaff  \
# 0  Developer: Business Intelligence (SSRS, PowerB...         Yes
# 1  DBA (Production Focus - build & troubleshoot s...          No
# 2  DBA (General - splits time evenly between writ...         Yes
# 3  DBA (Production Focus - build & troubleshoot s...          No
# 4  Developer: Business Intelligence (SSRS, PowerB...          No
#
#    YearsWithThisTypeOfJob OtherPeopleOnYourTeam DatabaseServers  \
# 0                       4                  None              10
# 1                      25                  None              10
# 2                       6                     1              10
# 3                       5                  None              10
# 4                       5                  None              10
#
#                         EmploymentSector  \
# 0                       Private business
# 1                       Private business
# 2                       Private business
# 3  Education (K-12, college, university)
# 4                       Private business
#
#                       CareerPlansThisYear Gender  Counter
# 0  Stay with the same employer, same role   Male        1
# 1  Stay with the same employer, same role   Male        1
# 2  Stay with the same employer, same role   Male        1
# 3  Stay with the same employer, same role   Male        1
# 4  Stay with the same employer, same role   Male        1

# %% [markdown]
# # Country Selection Options List

# %%
countries = df[['Country']].groupby(['Country']).count()

# Load country list as option for multi select dropdown select
optionsCountry =[{'label': "Select All", 'value': -1}]
for i in range(len(countries.index)):
    optionsCountry.append({'label': countries.index[i], 'value': countries.index[i]})

countries
# Out:
# Empty DataFrame
# Columns: []
# Index: [Albania, Argentina, Armenia, Australia, Austria, Bahrain, Bangladesh, Belarus, Belgium, Bermuda, Bolivia, Bosnia and Herzegovina, Brazil, Bulgaria, Canada, Cayman Islands, Chile, China, Colombia, Costa Rica, Croatia, Cyprus, Czech Republic, Denmark, Dominican Republic, Ecuador, El Salvador, Estonia, Finland, France, Georgia, Germany, Ghana, Greece, Guatemala, Guernsey, Honduras, Hong Kong, Hungary, Iceland, India, Indonesia, Iran, Ireland, Israel, Italy, Jamaica, Jersey, Jordan, Kenya, Latvia, Lithuania, Luxembourg, Macedonia, Malaysia, Maldives, Malta, Mexico, Moldova, Nepal, Netherlands, New Zealand, Nicaragua, Norway, Pakistan, Paraguay, Peru, Philippines, Poland, Portugal, Puerto Rico, Qatar, Romania, Russia, Saudi Arabia, Serbia and Montenegro, Singapore, Slovakia, Slovenia, South Africa, Spain, Swaziland, Sweden, Switzerland, Syria, Taiwan, Thailand, Turkey, Uganda, Ukraine, United Arab Emirates, United Kingdom, United States, Uruguay, Vanuatu, Venezuela, Vietnam]
#
# [97 rows x 0 columns]

# %% [markdown]
# ### Job Title and Gender selection lists

# %%
jobTitle=df['JobTitle'].unique()

genderList=df['Gender'].unique()

# %% [markdown]
# # Bootstrap Dashboard App

# %%
import dash
import dash_bootstrap_components as dbc
#from dash.dependencies import Input, Output
from dash import Input, Output, dcc, html

app = dash.Dash(external_stylesheets=[dbc.themes.BOOTSTRAP])

# the style arguments for the sidebar. We use position:fixed and a fixed width
SIDEBAR_STYLE = {
    "position": "fixed",
    "top": 0,
    "left": 0,
    "bottom": 0,
    "width": "16rem",
    "padding": "2rem 1rem",
    "background-color": "#f8f9fa",
}

# the styles for the main content position it to the right of the sidebar and
# add some padding.
CONTENT_STYLE = {
    "margin-left": "18rem",
    "margin-right": "2rem",
    "padding": "2rem 1rem",
}

sidebar = html.Div(
    [
        html.H2("Sidebar", className="display-4"),
        html.Hr(),
        dbc.Nav(
            [
                dbc.NavLink("Home", href="/", active="exact"),
                dbc.NavLink("Page 1", href="/page-1", active="exact"),
                dbc.NavLink("Page 2", href="/page-2", active="exact"),
            ],
            vertical=True,
            pills=True,
        ),

        html.Hr(),
        
        html.Label('Group By'),
        dcc.Dropdown(
            id="groupby",
            options= [{'label': 'Country', 'value': 'Country'},
                      {'label': 'Survey Year', 'value': 'Survey Year'},
                      {'label': 'Employment Sector', 'value': 'EmploymentSector'},
                      {'label': 'Employment Status', 'value': 'EmploymentStatus'},
                      {'label': 'Manage Staff', 'value': 'ManageStaff'},
                      {'label': 'Gender', 'value': 'Gender'},
                      {'label': 'Career Plans This Year', 'value': 'CareerPlansThisYear'}],
            value= 'Country',
        ),

        html.Label('Operation'),
        dcc.Dropdown(
            id="operation",
            options= [{'label': 'sum()', 'value': 'sum'},
                      {'label': 'count()', 'value': 'count'}],
            value= 'sum',
        ),

        html.Label('Country'),
        dcc.Dropdown(
            id="country",
            options= optionsCountry,
            value= -1,
            multi= True
        ),
        

    ],
    style=SIDEBAR_STYLE,
)

content = html.Div(id="page-content", style=CONTENT_STYLE)

app.layout = html.Div([dcc.Location(id="url"), sidebar, content])


@app.callback(Output("page-content", "children"), [Input("url", "pathname")])
def render_page_content(pathname):
    if pathname == "/":
        return dcc.Graph(id="graphCountry")
    elif pathname == "/page-1":
        return html.P("This is the content of page 1. Yay!")
    elif pathname == "/page-2":
        ############# Job Experince ###############
        return  [
                html.H1('Experince years histogram in a specified job title',
                        style={'textAlign':'center'}),
                        
                html.Br(),
                dcc.RadioItems(
                    id="gender-slider",
                    value="Female",
                    options=[
                            {"label": gender, "value": gender}
                            for gender in genderList],
                        
                ),
                html.Br(),
                dcc.Dropdown(id="slct_job",
                            options=[
                                {"label": job, "value": job} for job in jobTitle],
                            multi=False,
                            value="Manager",
                            ),
                
                

                dcc.Graph(id="Experince"),
                ]
            ############ End Job Experince ##############

    # If the user tries to reach a different page, return a 404 message
    return dbc.Jumbotron(
        [
            html.H1("404: Not found", className="text-danger"),
            html.Hr(),
            html.P(f"The pathname {pathname} was not recognised..."),
        ]
    )

@app.callback(Output('graphCountry', 'figure'), [Input("country", "value"),Input("groupby", "value"),Input("operation", "value"),])
def update_figure(val_country, val_groupby, val_operation):
    data = df

    if (val_country != -1):
        data = data[data["Country"].isin(val_country)]

    if (val_operation == 'sum'):
        data = data.groupby([val_groupby]).sum()
    if (val_operation == 'count'):
        data = data.groupby([val_groupby]).count()

    data = data.reset_index()

    return px.bar(
        data,
        x= val_groupby,
        y= "SalaryUSD"
    )

############# Job Experince ###############
@app.callback(
    Output('Experince', 'figure'),

    [Input("gender-slider", "value"),
    Input("slct_job", "value"),]
)  
def update_Experince(slctdGender, slctdJob):
    data = df.copy()

    data = data[data["Gender"] == slctdGender]
    data = data[data["JobTitle"] == slctdJob]

    fig = px.histogram(data, x="YearsWithThisTypeOfJob")

    return fig
############ End Job Experince ##############
    

if __name__ == "__main__":
    app.run_server(port=8888)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-9d9573114582> in <module>
#       1 import dash
# ----> 2 import dash_bootstrap_components as dbc
#       3 #from dash.dependencies import Input, Output
#       4 from dash import Input, Output, dcc, html
#       5
#
# ModuleNotFoundError: No module named 'dash_bootstrap_components'
